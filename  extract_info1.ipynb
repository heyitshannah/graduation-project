# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Base URL của trang công thức
base_url = "https://nutritionfacts.org/recipes/"
response = requests.get(base_url)
soup = BeautifulSoup(response.content, 'html.parser')

# Lấy các link công thức
recipe_links = soup.select("a.wpupg-type-wprm_recipe")
recipe_urls = [link.get('href') for link in recipe_links]

# Khởi tạo dictionary để lưu dữ liệu công thức
data = {
    "Recipe Name": [],
    "Servings": [],
    "Instruction Group": [],
    "Step": [],
    "Instructions": []
}

# Duyệt qua từng công thức để thu thập dữ liệu
for recipe_url in recipe_urls:
    response = requests.get(recipe_url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Lấy tên công thức
    recipe_name = soup.select_one("h1").get_text(strip=True)

    # Lấy thông tin servings
    serving_tag = soup.find('span', class_='wprm-recipe-servings')
    servings = serving_tag.get_text(strip=True) if serving_tag else 'N/A'

    # Lấy các nhóm hướng dẫn, có thể có thẻ h4 hoặc không
    instruction_groups = soup.find_all('div', class_='wprm-recipe-instruction-group')

    for group in instruction_groups:
        # Kiểm tra nếu có thẻ h4 thì lấy tên nhóm
        h4_tag = group.find('h4')
        instruction_group = h4_tag.get_text(strip=True) if h4_tag else ""

        # Duyệt qua từng bước hướng dẫn trong nhóm
        instruction_steps = group.find_all('li', class_='wprm-recipe-instruction')

        for idx, step in enumerate(instruction_steps, 1):  # Đếm step bắt đầu từ 1
            step_text = step.get_text(strip=True)

            # Lưu dữ liệu vào bảng
            data["Recipe Name"].append(recipe_name)
            data["Servings"].append(servings)
            data["Instruction Group"].append(instruction_group)
            data["Step"].append(f'Step {idx}')
            data["Instructions"].append(step_text)

    print(f"Thu thập xong hướng dẫn cho công thức: {recipe_name}")

# Tạo DataFrame từ dictionary
df = pd.DataFrame(data)

# Lưu dữ liệu vào file CSV
df.to_excel("recipes_instructions_grouped.xlsx", index=False)

print("Xuất dữ liệu ra file CSV thành công: recipes_instructions_grouped.csv")
# Out:
# Thu thập xong hướng dẫn cho công thức: Kale Pesto Basil Wraps
# Thu thập xong hướng dẫn cho công thức: Southwest Kale Salad with Cumin-Tomato Dressing
# Thu thập xong hướng dẫn cho công thức: Chickpea Chili
# Thu thập xong hướng dẫn cho công thức: Jicama Mango Salad
# Thu thập xong hướng dẫn cho công thức: Quinoa and Vegetable Stew
# Thu thập xong hướng dẫn cho công thức: Ultimate Sauce
# Thu thập xong hướng dẫn cho công thức: Cauliflower Bisque
# Thu thập xong hướng dẫn cho công thức: Cinnamon Roll Oatmeal
# Thu thập xong hướng dẫn cho công thức: Rainbow Root Veggie Stew
# Thu thập xong hướng dẫn cho công thức: Lentil–Quinoa Tacos
# Thu thập xong hướng dẫn cho công thức: Sweet Potato Mac N' Cheese
# Thu thập xong hướng dẫn cho công thức: Sweet and Smoky Dressing
# Thu thập xong hướng dẫn cho công thức: Plant-Based Zucchini Lasagna
# Thu thập xong hướng dẫn cho công thức: Chocolate–Cherry Nice Cream
# Thu thập xong hướng dẫn cho công thức: Peach and Papaya Salad
# Thu thập xong hướng dẫn cho công thức: Sensational Tahini–Dill Dressing
# Thu thập xong hướng dẫn cho công thức: Turmeric Tofu Scramble
# Thu thập xong hướng dẫn cho công thức: Lemon Cheesecake
# Thu thập xong hướng dẫn cho công thức: Summer Fun Salad
# Thu thập xong hướng dẫn cho công thức: Raspberry Power Balls
# Thu thập xong hướng dẫn cho công thức: Jicama Nachos
# Thu thập xong hướng dẫn cho công thức: Strawberry Salad
# Thu thập xong hướng dẫn cho công thức: Cauliflower Power Salad
# Thu thập xong hướng dẫn cho công thức: Mango-Raspberry Chia Pudding
# Thu thập xong hướng dẫn cho công thức: Mango Lime Tart
# Thu thập xong hướng dẫn cho công thức: Korean Soy Milk Noodles
# Thu thập xong hướng dẫn cho công thức: Marinated Tempeh and Vegetables
# Thu thập xong hướng dẫn cho công thức: Nut Cheese
# Thu thập xong hướng dẫn cho công thức: Ginger Carrot Soup
# Thu thập xong hướng dẫn cho công thức: Chickpea-Cauliflower Scramble
# Thu thập xong hướng dẫn cho công thức: Chakalaka
# Thu thập xong hướng dẫn cho công thức: Three-Bean Soup with Turmeric and Lentils
# Thu thập xong hướng dẫn cho công thức: Cheesy Broccoli Soup
# Thu thập xong hướng dẫn cho công thức: Groatnola
# Thu thập xong hướng dẫn cho công thức: Quinoa Kitchari
# Thu thập xong hướng dẫn cho công thức: Bok Choy Tofu Stir Fry
# Thu thập xong hướng dẫn cho công thức: Sweet Potato Taquitos
# Thu thập xong hướng dẫn cho công thức: Overnight Oats
# Thu thập xong hướng dẫn cho công thức: Hearty Veggie Soup
# Thu thập xong hướng dẫn cho công thức: Baked Grain Loaf with Umami Gravy
# Thu thập xong hướng dẫn cho công thức: Brownie Sandwich Cookies
# Thu thập xong hướng dẫn cho công thức: Red Beans and Quinoa
# Thu thập xong hướng dẫn cho công thức: Berry Banana Oatmeal Bowl
# Thu thập xong hướng dẫn cho công thức: Lentil Soup
# Thu thập xong hướng dẫn cho công thức: Champurrado
# Thu thập xong hướng dẫn cho công thức: Sheet Pan Meals
# Thu thập xong hướng dẫn cho công thức: Caramel Cocoa Bites
# Thu thập xong hướng dẫn cho công thức: Cinnamon Baked Apples
# Thu thập xong hướng dẫn cho công thức: Fruit and Nut Bars
# Thu thập xong hướng dẫn cho công thức: Southwest Quinoa Stew
# Thu thập xong hướng dẫn cho công thức: Cumin-Roasted Carrots with Chickpeas and Tomatoes
# Thu thập xong hướng dẫn cho công thức: Gemelli with Zucchini Meatballs and Avocado Chimichurri
# Thu thập xong hướng dẫn cho công thức: Rainbow Salad
# Thu thập xong hướng dẫn cho công thức: Garden Veggie Tempeh Scramble
# Thu thập xong hướng dẫn cho công thức: Stone Fruit Bowls
# Thu thập xong hướng dẫn cho công thức: Mango Blueberry Smoothie
# Thu thập xong hướng dẫn cho công thức: Pre-Workout Smoothie
# Thu thập xong hướng dẫn cho công thức: Oatmeal Cookie Dough Bites
# Thu thập xong hướng dẫn cho công thức: Banana Oat Cookies
# Thu thập xong hướng dẫn cho công thức: Super-Charged Spice Blend
# Thu thập xong hướng dẫn cho công thức: Barley Tabbouli Salad with Tahini Drizzle
# Thu thập xong hướng dẫn cho công thức: Curried Chickpea Wraps
# Thu thập xong hướng dẫn cho công thức: Yellow Split Pea Dal with Watercress
# Thu thập xong hướng dẫn cho công thức: Black Bean and Plantain Bowls with Mango Pico
# Thu thập xong hướng dẫn cho công thức: Buckwheat Soba & Edamame with Almond Butter Sauce
# Thu thập xong hướng dẫn cho công thức: Cottage Pie with Sweet Potato Mash
# Thu thập xong hướng dẫn cho công thức: Szechuan Tempeh and Broccoli
# Thu thập xong hướng dẫn cho công thức: Tart and Tangy Cran-Chocolate Pomegranate BROL Bowl
# Thu thập xong hướng dẫn cho công thức: Cauliflower Alfredo Linguine with Roasted Asparagus
# Thu thập xong hướng dẫn cho công thức: Baked Apples with Walnuts and Goji Berries
# Thu thập xong hướng dẫn cho công thức: Corn Chowder
# Thu thập xong hướng dẫn cho công thức: Ribollita with White Beans and Kale
# Thu thập xong hướng dẫn cho công thức: Umami Sauce Redux
# Thu thập xong hướng dẫn cho công thức: Roasted Kabocha with Kale-Cranberry Stuffing
# Thu thập xong hướng dẫn cho công thức: BROL Bowl with Sautéed Greens
# Thu thập xong hướng dẫn cho công thức: Light Vegetable Broth
# Thu thập xong hướng dẫn cho công thức: Basic BROL (Barley, Rye, Oats, and Lentils)
# Thu thập xong hướng dẫn cho công thức: Baked Purple Sweet Potato Fries
# Thu thập xong hướng dẫn cho công thức: Pumpkin Pie Smoothie
# Thu thập xong hướng dẫn cho công thức: Pumpkin Pie Custard
# Thu thập xong hướng dẫn cho công thức: Soba Noodle Soup
# Thu thập xong hướng dẫn cho công thức: Fudgy No-Bake Brownies
# Thu thập xong hướng dẫn cho công thức: Veggie Mac & Cheese
# Thu thập xong hướng dẫn cho công thức: Easy Veggie Tacos
# Thu thập xong hướng dẫn cho công thức: Unfried Refried Beans
# Thu thập xong hướng dẫn cho công thức: Fresh Guacamole
# Thu thập xong hướng dẫn cho công thức: Cashew Cream
# Thu thập xong hướng dẫn cho công thức: Simple Salsa
# Thu thập xong hướng dẫn cho công thức: Three-Bean Chili
# Thu thập xong hướng dẫn cho công thức: Baked Onion Rings
# Thu thập xong hướng dẫn cho công thức: Buffalo Cauliflower with Ranch Dressing
# Thu thập xong hướng dẫn cho công thức: Portobellos & Greens on Toast
# Thu thập xong hướng dẫn cho công thức: Harissa
# Thu thập xong hướng dẫn cho công thức: Lemon-Ginger Cooler
# Thu thập xong hướng dẫn cho công thức: Ranch Dressing
# Thu thập xong hướng dẫn cho công thức: Roasted Garlic
# Thu thập xong hướng dẫn cho công thức: Date Syrup
# Thu thập xong hướng dẫn cho công thức: Vegetable Broth
# Thu thập xong hướng dẫn cho công thức: Umami Sauce
# Thu thập xong hướng dẫn cho công thức: Spicy Ginger Vegetable Soup
# Thu thập xong hướng dẫn cho công thức: Vegetable Stacks With Tomato–Red Pepper Coulis
# Thu thập xong hướng dẫn cho công thức: Chickpea & Vegetable Tagine
# Thu thập xong hướng dẫn cho công thức: Balsamic Date Glaze
# Thu thập xong hướng dẫn cho công thức: Stuffed Sweet Potatoes with Balsamic Date Glaze
# Thu thập xong hướng dẫn cho công thức: Smoky Black-Eyed Peas & Collards
# Thu thập xong hướng dẫn cho công thức: Healthy Hot Sauce
# Thu thập xong hướng dẫn cho công thức: Super Salad With Garlic Caesar Dressing & Hemp Hearts
# Thu thập xong hướng dẫn cho công thức: Morning Grain Bowls
# Thu thập xong hướng dẫn cho công thức: Edamame Guacamole
# Thu thập xong hướng dẫn cho công thức: Berry Chocolate Chia Pudding
# Thu thập xong hướng dẫn cho công thức: Strawberry-Banana Nice Cream
# Thu thập xong hướng dẫn cho công thức: Black Bean Burgers
# Thu thập xong hướng dẫn cho công thức: V-12 Vegetable Blast
# Thu thập xong hướng dẫn cho công thức: Almond Milk
# Thu thập xong hướng dẫn cho công thức: Savory Spice Blend
# Thu thập xong hướng dẫn cho công thức: Nutty Parm
# Thu thập xong hướng dẫn cho công thức: Roasted Vegetable Lasagna
# Xuất dữ liệu ra file CSV thành công: recipes_instructions_grouped.csv
